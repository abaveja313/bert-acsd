# %%
import aspect_based_sentiment_analysis as absa

recognizer = absa.aux_models.BasicPatternRecognizer()
professor = absa.Professor(pattern_recognizer=recognizer)
nlp = absa.load(pattern_recognizer=recognizer)
# Out:
# Some layers from the model checkpoint at absa/classifier-rest-0.2 were not used when initializing BertABSClassifier: ['dropout_379']
# - This IS expected if you are initializing BertABSClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertABSClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of BertABSClassifier were not initialized from the model checkpoint at absa/classifier-rest-0.2 and are newly initialized: ['dropout_151']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
text = ("As stated in the business relationship about past issues, the incident with the bandwidth issue still remains unresolved or identified.  There were also many re-assignments of SMEs on the zscaler side so the focus was reset many times and tests had to be restarted/repeated for data tracking.")
print(f"Text Candidate:\n{text}")
# Out:
# Text Candidate:
# As stated in the business relationship about past issues, the incident with the bandwidth issue still remains unresolved or identified.  There were also many re-assignments of SMEs on the zscaler side so the focus was reset many times and tests had to be restarted/repeated for data tracking.

# %%
completed_task = nlp(text=text, aspects=[''])

# %%
scalability, = completed_task.examples

# %%
scalability
# Out:
# PredictedExample(text='As stated in the business relationship about past issues, the incident with the bandwidth issue still remains unresolved or identified.  There were also many re-assignments of SMEs on the zscaler side so the focus was reset many times and tests had to be restarted/repeated for data tracking.', aspect='relationship', sentiment=<Sentiment.neutral: 0>, text_tokens=['as', 'stated', 'in', 'the', 'business', 'relationship', 'about', 'past', 'issues', ',', 'the', 'incident', 'with', 'the', 'bandwidth', 'issue', 'still', 'remains', 'unresolved', 'or', 'identified', '.', 'there', 'were', 'also', 'many', 're', '-', 'assignments', 'of', 'smes', 'on', 'the', 'zscaler', 'side', 'so', 'the', 'focus', 'was', 'reset', 'many', 'times', 'and', 'tests', 'had', 'to', 'be', 'restarted', '/', 'repeated', 'for', 'data', 'tracking', '.'], text_subtokens=['as', 'stated', 'in', 'the', 'business', 'relationship', 'about', 'past', 'issues', ',', 'the', 'incident', 'with', 'the', 'bandwidt
# ...

# %%
absa.summary(scalability)
# Out:
# Sentiment.neutral for "relationship"
# Scores (neutral/negative/positive): [0.747 0.194 0.059]

# %%
absa.display(scalability.review)
# Out:
# <span style="background-color:rgba(180,180,180,1.1111111111111112);">Importance 1.00</span> <span style="background-color:rgba(135,206,250,0.125);">as</span> <span style="background-color:rgba(135,206,250,0.22499999999999998);">stated</span> <span style="background-color:rgba(135,206,250,0.3375);">in</span> <span style="background-color:rgba(135,206,250,0.3);">the</span> <span style="background-color:rgba(135,206,250,1.25);">business</span> <span style="background-color:rgba(135,206,250,1.25);">relationship</span> <span style="background-color:rgba(135,206,250,0.3);">about</span> <span style="background-color:rgba(135,206,250,0.075);">past</span> <span style="background-color:rgba(135,206,250,0.075);">issues</span> <span style="background-color:rgba(135,206,250,0.075);">,</span> <span style="background-color:rgba(135,206,250,0.0375);">the</span> <span style="background-color:rgba(135,206,250,0.075);">incident</span> <span style="background-color:rgba(135,206,250,0.0375);">with</span>
# ...
